# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
admissions_df = pd.read_csv(r'../Dataset/admissions.csv')
daily_metrics_df = pd.read_csv(r'../Dataset/daily_metrics.csv')
hospitals_df = pd.read_csv(r'../Dataset/hospitals.csv')        
main_admissions_df = pd.read_csv(r'../Dataset/main_admissions.csv')
main_daily_metrics_df = pd.read_csv(r'../Dataset/main_daily_metrics.csv')
wards_df = pd.read_csv(r'../Dataset/wards.csv')

# %%
main_admissions_df.head()
# Out:
#    admission_id        date  hospital_id ward_code arrival_source  \
# 0             1  2022-10-28            1        ED       referral
# 1             2  2022-10-28            1        ED      ambulance
# 2             3  2022-10-28            1        ED           self
# 3             4  2022-10-28            1        ED           self
# 4             5  2022-10-28            1        ED           self
#
#    triage_level  wait_minutes  length_of_stay_days      outcome  age sex  \
# 0           4.0           189                    0   discharged   48   M
# 1           4.0           189                    0  transferred   93   F
# 2           2.0           189                    0   discharged   52   M
# 3           3.0           189                    0   discharged   64   M
# 4           4.0           189                    0   discharged   59   M
#
#    procedure_flag
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
main_admissions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168731 entries, 0 to 168730
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   admission_id         168731 non-null  int64
#  1   date                 168731 non-null  object
#  2   hospital_id          168731 non-null  int64
#  3   ward_code            168731 non-null  object
#  4   arrival_source       168731 non-null  object
#  5   triage_level         52560 non-null   float64
#  6   wait_minutes         168731 non-null  int64
#  7   length_of_stay_days  168731 non-null  int64
#  8   outcome              168731 non-null  object
#  9   age                  168731 non-null  int64
#  10  sex                  168731 non-null  object
#  11  procedure_flag       168731 non-null  int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 15.4+ MB

# %%
admissions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿admission_id      545 non-null    int64
#  1   date                 545 non-null    object
#  2   hospital_id          545 non-null    int64
#  3   ward_code            545 non-null    object
#  4   arrival_source       545 non-null    object
#  5   triage_level         544 non-null    object
#  6   wait_minutes         545 non-null    int64
#  7   length_of_stay_days  545 non-null    int64
#  8   outcome              545 non-null    object
#  9   age                  545 non-null    int64
#  10  sex                  545 non-null    object
#  11  procedure_flag       544 non-null    float64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 51.2+ KB

# %%
admissions_df = admissions_df.rename(
    columns={"ï»¿admission_id": "admission_id"}
)

# %%
daily_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ï»¿date                 545 non-null    object
#  1   hospital_id             545 non-null    int64
#  2   ward_code               545 non-null    object
#  3   base_beds               545 non-null    int64
#  4   effective_capacity      545 non-null    int64
#  5   occupancy               545 non-null    int64
#  6   overflow                545 non-null    int64
#  7   admissions              545 non-null    int64
#  8   discharges              545 non-null    int64
#  9   staffing_index          545 non-null    float64
#  10  avg_wait_minutes        545 non-null    int64
#  11  admission_rate_per_bed  545 non-null    float64
#  12  discharge_rate_per_bed  545 non-null    float64
#  13  occupancy_rate          545 non-null    float64
# ...

# %%
daily_metrics_df = daily_metrics_df.rename(
    columns={"ï»¿date": "date"}
)

# %%
main_daily_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21428 entries, 0 to 21427
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    21428 non-null  object
#  1   hospital_id             21428 non-null  int64
#  2   ward_code               21428 non-null  object
#  3   base_beds               21428 non-null  int64
#  4   effective_capacity      21428 non-null  int64
#  5   occupancy               21428 non-null  int64
#  6   overflow                21428 non-null  int64
#  7   admissions              21428 non-null  int64
#  8   discharges              21428 non-null  int64
#  9   staffing_index          21428 non-null  float64
#  10  avg_wait_minutes        21428 non-null  int64
#  11  admission_rate_per_bed  21428 non-null  float64
#  12  discharge_rate_per_bed  21428 non-null  float64
#  13  occupancy_rate          21428 non-null  float64
# ...

# %%
admissions_data = pd.concat([main_admissions_df, admissions_df], axis =0 ,ignore_index=True)
metrics_data = pd.concat([main_daily_metrics_df, daily_metrics_df], axis=0,  ignore_index=True)

# %%
admissions_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169276 entries, 0 to 169275
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   admission_id         169276 non-null  int64
#  1   date                 169276 non-null  object
#  2   hospital_id          169276 non-null  int64
#  3   ward_code            169276 non-null  object
#  4   arrival_source       169276 non-null  object
#  5   triage_level         53104 non-null   object
#  6   wait_minutes         169276 non-null  int64
#  7   length_of_stay_days  169276 non-null  int64
#  8   outcome              169276 non-null  object
#  9   age                  169276 non-null  int64
#  10  sex                  169276 non-null  object
#  11  procedure_flag       169275 non-null  float64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 15.5+ MB

# %%
metrics_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21973 entries, 0 to 21972
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    21973 non-null  object
#  1   hospital_id             21973 non-null  int64
#  2   ward_code               21973 non-null  object
#  3   base_beds               21973 non-null  int64
#  4   effective_capacity      21973 non-null  int64
#  5   occupancy               21973 non-null  int64
#  6   overflow                21973 non-null  int64
#  7   admissions              21973 non-null  int64
#  8   discharges              21973 non-null  int64
#  9   staffing_index          21973 non-null  float64
#  10  avg_wait_minutes        21973 non-null  int64
#  11  admission_rate_per_bed  21973 non-null  float64
#  12  discharge_rate_per_bed  21973 non-null  float64
#  13  occupancy_rate          21973 non-null  float64
# ...

# %% [markdown]
# ### Initial EDA function

# %%
def initial_eda(dataframe, name):
  print(f"{name} dataframe information")
  print("="*60)
  print(dataframe.info())
  print("\n")
  print(f"{name} missing values information")
  print("="*60)
  print(dataframe.isnull().sum())
  print("\n")
  print(f"{name} description information")
  print("="*60)
  print(dataframe.describe())

# %% [markdown]
# #### admissions data eda

# %%
admissions_df.head()

# %%
initial_eda(admissions_df, "Admissions")
